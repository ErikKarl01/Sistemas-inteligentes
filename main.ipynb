# %%
import pandas as pd
import xlrd

arquivo = xlrd.open_workbook(r"C:\Users\kekin\OneDrive\Área de Trabalho\praicando\Sistemas inteligentes\cepea-consulta-20260511112037.xls", ignore_workbook_corruption=True)

planilha = arquivo.sheet_by_index(0)

dados = []

for i in range(planilha.nrows):
    dados.append(planilha.row_values(i))

df = pd.DataFrame(dados)

print(df)
# Out:
#                                                     0  \
# 0   Arroz | INDICADOR DO ARROZ EM CASCA CEPEA/IRGA-RS
# 1                                                Nota
# 2                                               Fonte
# 3                                                Data
# 4                                             01/2020
# ..                                                ...
# 76                                            01/2026
# 77                                            02/2026
# 78                                            03/2026
# 79                                            04/2026
# 80                                            05/2026
#
#                                                     1            2
# 0
# 1   por saca de 50 kg, tipo 1, 58/10, posto indúst...
# 2                                               Cepea
# 3                                          À vista R$  À vista US$
# 4                                               49,60        11,95
# ...

# %%
df.describe()
# Out:
#                                                         0      1   2
# count                                                  81     81  81
# unique                                                 81     80  77
# top     Arroz | INDICADOR DO ARROZ EM CASCA CEPEA/IRGA-RS  76,30
# freq                                                    1      2   3
